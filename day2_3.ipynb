# %% [markdown]
# <a href="https://colab.research.google.com/github/panjanathan28it-cmd/day1/blob/main/day2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import spacy
 nlp = spacy.load('en_core_web_sm')

# %%
from spacy.matcher import Matcher
matcher =Matcher(nlp.vocab)

# %%
from ast import pattern
pattern1=[{'LOWER': 'solarpower'}]
pattern2=[{'LOWER': 'solar'},{'LOWER': 'power'}]
pattern3=[{'LOWER': 'solar'},{'IS_PUNCT':True},{'LOWER': 'power'}]

# %%
matcher.add('SolarPower', [pattern1, pattern2, pattern3])

# %%
doc = nlp(u'The Solar Power industry continues to grow as demand \for solarpower increases. Solar-power cars are gaining popularity.')

# %%
found_matches = matcher(doc)
print(found_matches)
# Out:
# [(8656102463236116519, 1, 3), (8656102463236116519, 11, 12), (8656102463236116519, 14, 17)]

# %%
for match_id, start, end in found_matches:
  string_id = nlp.vocab.strings[match_id]
  span = doc[start:end]
  print(match_id, string_id, start, end, span.text)
# Out:
# 8656102463236116519 SolarPower 1 3 Solar Power
# 8656102463236116519 SolarPower 11 12 solarpower
# 8656102463236116519 SolarPower 14 17 Solar-power

# %%
doc2 = nlp(u'Solar-power energy runs solar-power cars.')

# %%
found_matches = matcher(doc2)
print(found_matches)
# Out:
# [(8656102463236116519, 0, 3), (8656102463236116519, 5, 8)]

# %%
matcher.remove('SolarPower')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1968700632.py in <cell line: 0>()
# ----> 1 matcher.remove('SolarPower')
#
# /usr/local/lib/python3.12/dist-packages/spacy/matcher/matcher.pyx in spacy.matcher.matcher.Matcher.remove()
#
# ValueError: [E175] Can't remove rule for unknown match pattern ID: SolarPower

# %%
pattern1=[{'LOWER': 'solarpower'}]
pattern2=[{'LOWER': 'solar'},{'IS_PUNCT':True,'op':'*'},{'LOWER': 'power'}]
pattern3=[{'LOWER': 'solarpowered'}]
pattern2=[{'LOWER': 'solar'},{'IS_PUNCT':True,'op':'*'},{'LOWER': 'powered'}]

# %%
matcher.add('SolarPower', [pattern1, pattern2, pattern3,pattern4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2707864062.py in <cell line: 0>()
# ----> 1 matcher.add('SolarPower', [pattern1, pattern2, pattern3,pattern4])
#
# NameError: name 'pattern4' is not defined

# %%
found_matches = matcher(doc2)
print(found_matches)
# Out:
# []
# /tmp/ipython-input-4209548175.py:1: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   found_matches = matcher(doc2)

# %%
from spacy.matcher import PhraseMatcher
matcher = PhraseMatcher(nlp.vocab)

# %%
pwd
# Out:
# '/content'

# %%
with open('reaganomics.txt',encoding='cp1252') as f:
  doc3 = nlp(f.read())

# %%
phrase_list = ['voodoo economics','supply-side economics','trickle-down economics','free-market economics']

# %%
phrase_patterns = [nlp(text) for text in phrase_list]

# %%
matches =matcher(doc3)

# %%
matches
# Out:
# []

# %%
doc3[665:685]
# Out:
# same time he attracted a following from the supply-side economics movement, which formed in opposition to Keynesian

# %%
doc3[2975:2995]
# Out:
# ) lawsuits against institutions.[66] His policies became widely known as "trickle-down economics", due to

# %%
sents = [sent for sent in doc3.sents]

print(sents[0].start,sents[0].end)
# Out:
# 0 35

# %%
for sent in sents:
  if matches:
    if matches[4][1] < sent.end:
        print(sent)
        break
  else:
    print('no mathes ')
    break
# Out:
# no mathes
