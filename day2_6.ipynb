# %% [markdown]
# <a href="https://colab.research.google.com/github/panjanathan28it-cmd/day1/blob/main/day2_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import spacy
 nlp = spacy.load('en_core_web_sm')

# %%
doc=nlp(u'This is the first sentence. this is another sentence. this is last sentence.')
for sent in doc.sents:
  print(sent)
# Out:
# This is the first sentence.
# this is another sentence.
# this is last sentence.

# %%
print(doc[1])
# Out:
# is

# %%
sentences = list (doc.sents)
print(sentences[1])
# Out:
# this is another sentence.

# %%
doc_sents = [sent for sent in doc.sents]
doc_sents
# Out:
# [This is the first sentence.,
#  this is another sentence.,
#  this is last sentence.]

# %%
print(doc_sents[1])
# Out:
# this is another sentence.

# %%
type(doc_sents[1])
# Out:
# spacy.tokens.span.Span

# %%
print(doc_sents[1].start, doc_sents[1].end)
# Out:
# 6 11

# %%
doc = nlp(u'"management is doing thingsright;leadership is doing the right things." -peter drucker')

for sent in doc.sents:
  print(sent)
  print('\n')
# Out:
# "management is doing thingsright;leadership is doing the right things."
#
#
# -peter drucker

# %%
doc
# Out:
# "management is doing thingsright;leadership is doing the right things." -peter drucker

# %%
doc[:-1]
# Out:
# "management is doing thingsright;leadership is doing the right things." -peter

# %%
doc[:-2]
# Out:
# "management is doing thingsright;leadership is doing the right things."

# %%
from spacy.language import Language
@Language.component("set_custom_boundaries")

def set_custom_boundaries(doc):
  for token in doc[:-1]:
    if token.text == ';':
      doc[token.i+1].is_sent_start = True
  return doc

# %%
nlp.add_pipe("set_custom_boundaries", after='parser')
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'parser', 'set_custom_boundaries', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc4 = nlp(u'"management is doing thingsright;leadership is doing the right things."-peter drucker')

for sent in doc4.sents:
  print(sent)
# Out:
# "management is doing thingsright;leadership is doing the right things.
# "-peter drucker

# %%
doc4[4]
# Out:
# thingsright;leadership

# %%
doc4[5].is_sent_start = True
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2168833848.py in <cell line: 0>()
# ----> 1 doc4[5].is_sent_start = True
#
# /usr/local/lib/python3.12/dist-packages/spacy/tokens/token.pyx in spacy.tokens.token.Token.is_sent_start.__set__()
#
# ValueError: [E043] Refusing to write to token.sent_start if its document is parsed, because this may cause inconsistent state.

# %%
nlp = spacy.load('en_core_web_sm')

mystring = u"this is a sentence. this is another. \n\nthis is a \nthird sentence."

doc = nlp(mystring)

for sent in doc.sents:
  print([token.text for token in sent])
# Out:
# ['this', 'is', 'a', 'sentence', '.']
# ['this', 'is', 'another', '.', '\n\n']
# ['this', 'is', 'a', '\n', 'third', 'sentence', '.']
