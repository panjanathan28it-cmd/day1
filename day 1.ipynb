# %%
name = 'barath'
print('my name is {var}.'.format(var=name))
# Out:
# my name is barath.

# %%
name = 'barath'
course = "advanced AI"

message = f"my name is {name} and iam learning {course}."
print(message)
# Out:
# my name is barath and iam learning advanced AI.

# %%
name = 'barath'
print(f'his name is {name!r}')
# Out:
# his name is 'barath'

# %%
d = {'a':123,'b':456}
print(f'Address: {d["a"]} main street')
# Out:
# Address: 123 main street

# %%
library=[("author","topic","page"),("twain","rafting",601),("feynman","physics",95),("hamiton","mythology",144)]

for book in library:
    print(f"{book[0]:{10}} {book[1]:{8}} {book[2]:{7}}")
# Out:
# author     topic    page
# twain      rafting      601
# feynman    physics       95
# hamiton    mythology     144

# %%
for book in library:
    print(f"{book[0]:{10}} {book[1]:{10}} {book[2]:.>{7}}")
# Out:
# author     topic      ...page
# twain      rafting    ....601
# feynman    physics    .....95
# hamiton    mythology  ....144

# %%
from datetime import datetime
today = datetime(year=2018, month=1, day=27)
print(f"{today:%B %d, %Y}")
# Out:
# January 27, 2018

# %%
# %%writefile LOYOLA.txt
# hello, this is a quick test file.
# this is the second line of the file
# Out:
# Writing LOYOLA.txt

# %%
my_file = open("LOYOLA.txt")

# %%
my_file.read()
# Out:
# 'hello, this is a quick test file.\nthis is the second line of the file\n'

# %%
pwd
# Out:
# 'C:\\Users\\24IT017'

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.seek(0)
my_file.readlines()
# Out:
# ['hello, this is a quick test file.\n',
#  'this is the second line of the file\n']

# %%
my_file.close()

# %%
my_file=open("LOYOLA.txt","w+")

# %%
my_file.write("This is a new first line")
# Out:
# 24

# %%
my_file.seek(0)
my_file.read()
# Out:
# 'this is a new first line'

# %%
my_file.close()

# %%
my_file=open("LOYOLA.txt","a+")
my_file.write("\nThis line is being appended to test.txt")
my_file.write("\nAnd another line here.")
# Out:
# 23

# %%
my_file.seek(0)
print(my_file.read())
# Out:
# this is a new first line
# This line is being appended to test.txt
# And another line here.

# %%
with open("LOYOLA.txt","r") as txt:
    first_line = txt.readlines()[0]
    
print(first_line)
# Out:
# this is a new first line

# %%
with open("LOYOLA.txt","r") as txt:
    for line in txt:
        print(line, end="")
# Out:
# this is a new first line
# This line is being appended to test.txt
# And another line here.
