# %%
# !pip install pypdf
from pypdf import PdfReader
reader = PdfReader("business_proposal.pdf")
len(reader.pages)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pypdf in c:\users\24it017\appdata\roaming\python\python39\site-packages (6.7.2)
# Requirement already satisfied: typing_extensions>=4.0 in c:\programdata\anaconda3\lib\site-packages (from pypdf) (4.3.0)
# 2

# %%
page_one = reader.pages[1]
page_one_text=page_one.extract_text()
print(page_one_text)
f.close()
# Out:
# AUTHORS:
# Amy Baker, Finance Chair, x345, abaker@ourcompany.com
# Chris Donaldson, Accounting Dir., x621, cdonaldson@ourcompany.com
# Erin Freeman, Sr. VP, x879, efreeman@ourcompany.com
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17108\2636035325.py in <module>
#       2 page_one_text=page_one.extract_text()
#       3 print(page_one_text)
# ----> 4 f.close()
#
# NameError: name 'f' is not defined

# %%
reader = PdfReader("business_proposal.pdf")
len(reader.pages)
# Out:
# 2

# %%
page_one = reader.pages[1]
page_one_text=page_one.extract_text()
print(page_one_text)
reader.close()
# Out:
# AUTHORS:
# Amy Baker, Finance Chair, x345, abaker@ourcompany.com
# Chris Donaldson, Accounting Dir., x621, cdonaldson@ourcompany.com
# Erin Freeman, Sr. VP, x879, efreeman@ourcompany.com
